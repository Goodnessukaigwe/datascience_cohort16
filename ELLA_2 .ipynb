# %%
heading =" Creating Variables for My Information"

# %%
print(heading)
# Out:
#  Creating Variables for My Information

# %%
full_name ="Graziaella D.Lawrence"

# %%
school_name="Colab Tech. School"

# %%
age="28"

# %%
favorite_subject="data science"

# %%
print("sentence introducing me with my variables using 3 strings method")
# Out:
# sentence introducing me with my variables using 3 strings method

# %%
print("my name is " + full_name .upper() +".")
# Out:
# my name is GRAZIAELLA D.LAWRENCE.

# %%
print("I am" + ("28") +" years old.")
# Out:
# I am28 years old.

# %%
print("I attend"+  school_name.title() + " and my favorite subject is" +  favorite_subject.capitalize() + ".")
# Out:
# I attendColab Tech. School and my favorite subject isData science.

# %%
heading="Creating Varaible Quote"

# %%
print (heading)
# Out:
# Creating Varaible Quote

# %%
quote="Don't let the fear of striking out keep you from playing the game"

# %%
print(quote.upper())
# Out:
# DON'T LET THE FEAR OF STRIKING OUT KEEP YOU FROM PLAYING THE GAME

# %%
print(quote.lower())
# Out:
# don't let the fear of striking out keep you from playing the game

# %%
print(quote.swapcase())
# Out:
# dON'T LET THE FEAR OF STRIKING OUT KEEP YOU FROM PLAYING THE GAME

# %%
print(quote.replace ("the fear","doubt"))
# Out:
# Don't let doubt of striking out keep you from playing the game

# %%
best_friend=("what is your best friends name?")

# %%
print("what is your best friends name?")
# Out:
# what is your best friends name?

# %%
best_friend="Lois"

# %%
print(best_friend.upper())
# Out:
# LOIS

# %%
print("my best friend is" +   best_friend .title()   +  "and"  "she is a nurse ")
# Out:
# my best friend isLoisandshe is a nurse

# %%
heading="Short Story"

# %%
print(heading)
# Out:
# Short Story

# %%
print(full_name    + " and"    +     best_friend.title() +    "are nurses who decided to learn  a  new skills in the tech. world"     +   favorite_subject + 
"together at"     +    school_name,   "they are passionate to learn"    +    "and"   +     "don't doubt their potentials:   \"" +    quote + "\"")
# Out:
# Graziaella D.Lawrence andLoisare nurses who decided to learn  a  new skills in the tech. worlddata sciencetogether atColab Tech. School they are passionate to learnanddon't doubt their potentials:   "Don't let the fear of striking out keep you from playing the game"

# %%
print(full_name    + " and"    +     best_friend.title() +    "are nurses who decided to learn  a  new skills in the tech. world"     +   favorite_subject + 
"together at"     +    school_name,   "they are passionate to learn"    +    "and"   +     "don't doubt their potentials:   \"" +    quote + "\"")
# Out:
# Graziaella D.Lawrence andLoisare nurses who decided to learn  a  new skills in the tech. worlddata sciencetogether atColab Tech. School they are passionate to learnanddon't doubt their potentials:   "Don't let the fear of striking out keep you from playing the game"

# %%
print (heading)
print(full_name)
print(school_name)
print("age")
print (favorite_subject)
print("sentence introducing me with my variables using 3 strings methods")
print("my name is " + full_name .upper() +".")
print("I am" + ("28") +" years old.")
print("I attend"+  school_name.title() + " and my favorite subject is" +  favorite_subject.capitalize() + ".")
print(heading)
print(quote.upper())
print(quote.lower())
print(quote.swapcase())
print(quote.replace ("the fear","doubt"))
print("what is your best friends name?")
print(best_friend.upper())
print("my best friend is" +   best_friend .title()   +  "and"  "she is a nurse ")
print(heading)
print(full_name    + " and"    +     best_friend.title() +    "are nurses who decided to learn  a  new skills in the tech. world"     +   favorite_subject + 
"together at"     +    school_name,   "they are passionate to learn"    +    "and"   +     "don't doubt their potentials:   \"" +    quote + "\"")
# Out:
# Short Story
# Graziaella D.Lawrence
# Colab Tech. School
# age
# data science
# sentence introducing me with my variables using 3 strings methods
# my name is GRAZIAELLA D.LAWRENCE.
# I am28 years old.
# I attendColab Tech. School and my favorite subject isData science.
# Short Story
# DON'T LET THE FEAR OF STRIKING OUT KEEP YOU FROM PLAYING THE GAME
# don't let the fear of striking out keep you from playing the game
# dON'T LET THE FEAR OF STRIKING OUT KEEP YOU FROM PLAYING THE GAME
# Don't let doubt of striking out keep you from playing the game
# what is your best friends name?
# LOIS
# my best friend isLoisandshe is a nurse
# Short Story
# Graziaella D.Lawrence andLoisare nurses who decided to learn  a  new skills in the tech. worlddata sciencetogether atColab Tech. School they are passionate to learnanddon't doubt their potentials:   "Don't let the fear of striking out keep you from playing the game"
